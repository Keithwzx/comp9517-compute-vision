# %%
# z5140893
# Chengze Du

# %%
# Task 1

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# read the img
img=cv2.imread('light_rail.jpg')

# %%
# split img color channel to B,G,R
b,g,r=cv2.split(img)

# %%
# add the matrix together as the formula
I = 0.299*r + 0.587*g + 0.114*b
I
# Out:
# array([[243.929, 243.929, 243.929, ..., 243.929, 243.929, 243.929],
#        [243.929, 243.929, 243.929, ..., 243.929, 243.929, 243.929],
#        [243.929, 243.929, 243.929, ..., 243.929, 243.929, 243.929],
#        ...,
#        [ 59.   ,  60.   ,  61.   , ...,  95.017,  39.903,  34.587],
#        [ 64.   ,  64.   ,  64.   , ..., 119.017,  65.789,  33.402],
#        [ 56.   ,  58.   ,  61.   , ..., 147.789, 102.789,  54.148]])

# %%
# use matplotlib.pyplot to show the gray level img
plt.imshow(I,'gray')
# plt.axis('off')
cv2.imwrite('task1_cv.png',I)
# Out:
# True

# %%
# my pc crushes when using cv2 to show the picture
# cv2.imshow('img',I)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# Task 2

# %%
# read the img as I produced from task 1
I=cv2.imread('task1_cv.png', 0)

# %%
# get the size of the picture
rows, cols = I.shape
rows, cols
# Out:
# (1080, 1080)

# %%
# in this assignment, we sue random value in final result
import random
from time import time
# define a function. The first parameter is window_size: 3,5,7...
# The second parameter is 'median' or 'max' or 'min' or 'random' of the list of the most frequent pixel
def spatial_filting(window_size, num_position):
    # If the window_size is out of the img, we need padding, so get the padding length
    #(which is also the distance from margin pixel to the central pixel in the window_size):
    pad_length=(window_size-1)//2
    rows,cols=I.shape
    begin = time()
    for row in range(0, rows):
        for col in range(0, cols):
            # get the theoretic location/coordinates of the window_size's borders
            window_up=row-pad_length
            window_down=pad_length+row
            window_left=col-pad_length
            window_right=pad_length+col
            # get the real location/coordinates that the window_size's borders should be 
            if window_up<0:
                window_up=0
            if window_left<0:
                window_left=0
            if window_down>rows-1:
                window_down=rows-1
            if window_right>cols-1:
                window_right=cols-1
            # get the neighbourhood(window_size)
            neighbourhood=I[window_up:window_down+1, window_left:window_right+1]
            # use cv2 histogram to calculate frequency.(Could use np.histogram to optimise time cost)
            hist = cv2.calcHist([neighbourhood], [0], None, [256], [0, 256]) #0.002
            # get the mmost frequent pixels (may be more than one number).
            max_pixels=np.where(hist==np.max(hist))[0] #0.0001
            # use 'median' or 'max' or 'min' or 'random' number of the most frequent pixel as the centre point's pixel
            if num_position=='median':
                J[row][col]=np.median(max_pixels)
            if num_position=='max':
                J[row][col]=np.max(max_pixels)
            if num_position=='min':
                J[row][col]=np.min(max_pixels)
            if num_position=='random':
                random_int=random.randint(0,len(max_pixels)-1)
                J[row][col]=max_pixels[random_int]
    end = time()
    print(end - begin)

# %%
# create a copy of I
J=I.copy()
spatial_filting(5, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_5x5.png', J)
# Out:
# 83.26042819023132
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(11, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_11x11.png', J)
# Out:
# 92.21468997001648
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(17, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_17x17.png', J)
# Out:
# 87.51814603805542
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(23, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_23x23.png', J)
# Out:
# 97.23425269126892
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(29, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_29x29.png', J)
# Out:
# 104.08975005149841
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(35, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_35x35.png', J)
# Out:
# 124.13413095474243
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(41, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_41x41.png', J)
# Out:
# 110.10462498664856
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(47, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_47x47.png', J)
# Out:
# 102.3610680103302
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(53, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_53x53.png', J)
# Out:
# 91.77267718315125
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(59, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_59x59.png', J)
# Out:
# 111.60842490196228
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(65, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_65x65.png', J)
# Out:
# 126.21012711524963
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(71, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_71x71.png', J)
# Out:
# 111.65515398979187
# True

# %%
# create a copy of I
J=I.copy()
spatial_filting(77, 'random')
plt.imshow(J, 'gray')
cv2.imwrite('task2_random_77x77.png', J)
# Out:
# 132.82121324539185
# True

# %%
# Task 3

# %%
def oil_filting(window_size, img_name):
    J = cv2.imread(img_name,0)
    rows,cols=J.shape
    # If the window_size is out of the img, we need padding, so get the padding length
    #(which is also the distance from margin pixel to the central pixel in the window_size):
    pad_length=(window_size-1)//2
    begin = time()
    for row in range(0, rows):
        for col in range(0, cols):
            # get the theoretic location/coordinates of the window_size's borders
            window_up=row-pad_length
            diff_up=0
            window_down=pad_length+row
            window_left=col-pad_length
            diff_left=0
            window_right=pad_length+col
            # get the real location/coordinates that the window_size's borders should be
            # also get the coordinate distance difference between theoretic neighborhood border and image border(diff_up,diff_left)
            if window_up<0:
                diff_up=abs(window_up)
                window_up=0
            if window_left<0:
                diff_left=abs(window_left)
                window_left=0
            if window_down>rows-1:
                window_down=rows-1
            if window_right>cols-1:
                window_right=cols-1
            # get the central point coordinates of the window size:
            mask_center_row=pad_length-diff_up
            mask_center_col=pad_length-diff_left
            # get the neighbourhood(window_size)
            neighbourhood=J[window_up:window_down+1, window_left:window_right+1]
            # get the coordinate of the points which have the same pixel value as central value in the neighborhood
            a, b=np.where(neighbourhood==J[row,col])
            # transfer the neighborhood coordinate to the image coordinate. Thus find the position of these points in image
            row_B=a+row-mask_center_row
            col_B=b+col-mask_center_col
            # get the matrix of these points' colour intensities
            same_value_matrix=B[row_B,col_B]
            # get the average intensities of these pixels
            new_color=np.mean(same_value_matrix,axis=0)
            # change the cantral colour intensity with the average intensities of those pixels
            B[row,col]=new_color
    end = time()
    print(end - begin)

# %%
B = img.copy()
oil_filting(5, 'task2_random_5x5.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_5x5.png', B)
# Out:
# 97.76775002479553
# True

# %%
B = img.copy()
oil_filting(11, 'task2_random_11x11.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_11x11.png', B)
# Out:
# 109.86900305747986
# True

# %%
B = img.copy()
oil_filting(17, 'task2_random_17x17.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_17x17.png', B)
# Out:
# 112.09617924690247
# True

# %%
B = img.copy()
oil_filting(23, 'task2_random_23x23.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_23x23.png', B)
# Out:
# 129.86506390571594
# True

# %%
B = img.copy()
oil_filting(29, 'task2_random_29x29.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_29x29.png', B)
# Out:
# 159.843590259552
# True

# %%
B = img.copy()
oil_filting(35, 'task2_random_35x35.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_35x35.png', B)
# Out:
# 198.3113830089569
# True

# %%
B = img.copy()
oil_filting(41, 'task2_random_41x41.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_41x41.png', B)
# Out:
# 191.28630805015564
# True

# %%
B = img.copy()
oil_filting(47, 'task2_random_47x47.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_47x47.png', B)
# Out:
# 217.4922502040863
# True

# %%
B = img.copy()
oil_filting(53, 'task2_random_53x53.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_53x53.png', B)
# Out:
# 270.3417012691498
# True

# %%
B = img.copy()
oil_filting(59, 'task2_random_59x59.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_59x59.png', B)
# Out:
# 256.06343388557434
# True

# %%
B = img.copy()
oil_filting(65, 'task2_random_65x65.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_65x65.png', B)
# Out:
# 287.17654609680176
# True

# %%
B = img.copy()
oil_filting(71, 'task2_random_71x71.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_71x71.png', B)
# Out:
# 316.6307899951935
# True

# %%
B = img.copy()
oil_filting(77, 'task2_random_77x77.png')
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
cv2.imwrite('task3_77x77.png', B)
# Out:
# 330.3795940876007
# True
